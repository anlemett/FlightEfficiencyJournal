# %%
# %matplotlib inline

seed_value = 100
import os
os.environ['PYTHONHASHSEED']=str(seed_value)
import random
random.seed(seed_value)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn import metrics
import statsmodels.api as sm
from scipy import stats

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Data uploading

# %%
AIRPORT_ICAO = "ESGG"
#AIRPORT_ICAO = "ESSA"

DATA_DIR = os.path.join("..", "..")
DATA_DIR = os.path.join(DATA_DIR, "Data")
DATA_DIR = os.path.join(DATA_DIR, "Weather")
DATA_DIR = os.path.join(DATA_DIR, AIRPORT_ICAO)

# AIF
filename = AIRPORT_ICAO + "_2019_01_06_mean_by_lat_lon.csv"
full_filename = os.path.join(DATA_DIR, filename)
weather_df1 = pd.read_csv(full_filename, sep=' ')

filename = AIRPORT_ICAO + "_2019_07_12_mean_by_lat_lon.csv"
full_filename = os.path.join(DATA_DIR, filename)
weather_df2 = pd.read_csv(full_filename, sep=' ')

filename = AIRPORT_ICAO + "_2020_01_06_mean_by_lat_lon.csv"
full_filename = os.path.join(DATA_DIR, filename)
weather_df3 = pd.read_csv(full_filename, sep=' ')

filename = AIRPORT_ICAO + "_2020_07_12_mean_by_lat_lon.csv"
full_filename = os.path.join(DATA_DIR, filename)
weather_df4 = pd.read_csv(full_filename, sep=' ')

weather_df = pd.concat([weather_df1, weather_df2, weather_df3, weather_df4], axis=0)
weather_df.reset_index(inplace = True, drop = True)

pd.set_option('display.max_columns', None)

features_df = weather_df.drop('month', axis=1, inplace=False)
features_df = features_df.drop('day', axis=1, inplace=False)
features_df = features_df.drop('hour', axis=1, inplace=False)
features_df = features_df.drop('u10', axis=1, inplace=False)
features_df = features_df.drop('v10', axis=1, inplace=False)
features_df = features_df.drop('u100', axis=1, inplace=False)
features_df = features_df.drop('v100', axis=1, inplace=False)
features_df = features_df.drop('cin', axis=1, inplace=False)

while features_df['cbh'].isnull().sum().sum()>0:
    features_df['cbh'] = features_df['cbh'].fillna(features_df['cbh'].rolling(window=2, min_periods=1).mean())

features = features_df.columns
print(features)

# Separating out the features
data = features_df.loc[:, features].values

# Normalizing the features
data_rescaled = MinMaxScaler().fit_transform(data)

#print(data_rescaled)
data_rescaled[:,0] = 1 - data_rescaled[:,0] # cbh

# Standardizing the features
data_rescaled = StandardScaler().fit_transform(data_rescaled)

features_rescaled = pd.DataFrame(data_rescaled)
# Out:
# Index(['cbh', 'cape', 'cp', 'csf', 'csfr', 'hcc', 'i10fg', 'kx', 'lsf',
#        'lssfr', 'lcc', 'mcc', 'sf', 'tcc', 'tciw', 'tclw', 'tcrw', 'tcsw',
#        'tcw', 'tp', 'wind10', 'wind100'],
#       dtype='object')

# %%
corr = features_rescaled.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_f77c5_row0_col0,#T_f77c5_row1_col1,#T_f77c5_row2_col2,#T_f77c5_row3_col3,#T_f77c5_row4_col4,#T_f77c5_row5_col5,#T_f77c5_row6_col6,#T_f77c5_row7_col7,#T_f77c5_row8_col8,#T_f77c5_row9_col9,#T_f77c5_row10_col10,#T_f77c5_row11_col11,#T_f77c5_row12_col12,#T_f77c5_row13_col13,#T_f77c5_row14_col14,#T_f77c5_row15_col15,#T_f77c5_row16_col16,#T_f77c5_row17_col17,#T_f77c5_row18_col18,#T_f77c5_row19_col19,#T_f77c5_row20_col20,#T_f77c5_row21_col21{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T

#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_f77c5_row1_col2,#T_f77c5_row16_col2,#T_f77c5_row17_col12,#T_f77c5_row19_col21{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_f77c5_row1_col3,#T_f77c5_row1_col4{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_f77c5_row1_col7,#T_f77c5_row4_col8,#T_f77c5_row5_col18,#T_f77c5_row10_col20,#T_f77c5_row13_col19,#T_f77c5_row20_col15{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_f77c5_row1_col8,#T_f77c5_row1_col9,#T_f77c5_row3_col0,#T_f77c5_row10_col1{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_f77c5_row1_col12,#T_f77c5_row6_col7,#T_f77c5_row6_col18,#T_f77c5_row12_col7,#T_f77c5_row18_col21{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_f77c5_row1_col16,#T_f77c5_row6_col1{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_f77c5_row1_col18{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_f77c5_row1_col19,#T_f77c5_row4_col13,#T_f77c5_row8_col0,#T_f77c5_row9_col0,#T_f77c5_row16_col3{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_f77c5_row2_col1{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_f77c5_row2_col3,#T_f77c5_row6_col12,#T_f77c5_row12_col19,#T_f77c5_row14_col0,#T_f77c5_row14_col3,#T_f77c5_row20_col8,#T_f77c5_row21_col8{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_f77c5_row2_col5,#T_f77c5_row12_col13,#T_f77c5_row21_col5{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_f77c5_row2_col6,#T_f77c5_row5_col21,#T_f77c5_row7_col17,#T_f77c5_row20_col0,#T_f77c5_row21_col11,#T_f77c5_row21_col17{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_f77c5_row2_col7{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_f77c5_row2_col8,#T_f77c5_row2_col9,#T_f77c5_row12_col0,#T_f77c5_row16_col8{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_f77c5_row2_col10,#T_f77c5_row13_col6,#T_f77c5_row18_col17,#T_f77c5_row21_col0{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_f77c5_row2_col11,#T_f77c5_row9_col4,#T_f77c5_row10_col17,#T_f77c5_row11_col9,#T_f77c5_row14_col20,#T_f77c5_row17_col20{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_f77c5_row2_col12,#T_f77c5_row5_col4,#T_f77c5_row15_col1,#T_f77c5_row20_col4,#T_f77c5_row21_col4{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_f77c5_row2_col13,#T_f77c5_row6_col16,#T_f77c5_row8_col21,#T_f77c5_row12_col21,#T_f77c5_row13_col12,#T_f77c5_row18_col5,#T_f77c5_row20_col19{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_f77c5_row2_col15,#T_f77c5_row4_col9,#T_f77c5_row13_col0,#T_f77c5_row15_col2,#T_f77c5_row15_col5{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_f77c5_row2_col16,#T_f77c5_row7_col1,#T_f77c5_row14_col9{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_f77c5_row2_col17,#T_f77c5_row5_col19,#T_f77c5_row8_col14,#T_f77c5_row9_col11{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_f77c5_row2_col18,#T_f77c5_row19_col10{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_f77c5_row2_col19,#T_f77c5_row14_col19{
#             background-color:  #f6bea4;
#             color:  #000000;
#         }#T_f77c5_row2_col20,#T_f77c5_row17_col7,#T_f77c5_row18_col10,#T_f77c5_row19_col0,#T_f77c5_row20_col17{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_f77c5_row2_col21,#T_f77c5_row6_col0,#T_f77c5_row6_col17,#T_f77c5_row10_col18{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_f77c5_row3_col1,#T_f77c5_row9_col15,#T_f77c5_row12_col15,#T_f77c5_row16_col12{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_f77c5_row3_col2,#T_f77c5_
